# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n=200
lol = np.hstack([np.ones(n//2), np.ones(n//2)*0.5])
plt.plot(lol/lol.sum())
plt.xlabel('Words')
plt.ylabel('Probabilities')
# Out:
# Text(0, 0.5, 'Probabilities')

# %%
test = np.random.exponential(1, n)
test = -np.sort(-test)
plt.plot(test/ test.sum())
plt.axvline(60, c='red')
plt.xlabel('Words')
plt.ylabel('Probabilities')
# Out:
# Text(0, 0.5, 'Probabilities')

# %%
test = np.hstack([np.random.uniform(0.8,1, 100), np.random.uniform(0,0.8, 10), np.random.uniform(0,0.2, 50)])
test = -np.sort(-test)
plt.plot(test/ test.sum())
plt.xlabel('Words')
plt.axvline(110, c='red')
plt.ylabel('Probabilities')
# Out:
# Text(0, 0.5, 'Probabilities')
