# %%
# the only thing that needs to be detokenized is punctuation being separated by a space. And there being newline characters. (should these be replaced??)

from sacremoses import MosesTokenizer, MosesDetokenizer
import pandas as pd
md = MosesDetokenizer(lang='en')

for variant in ['test']:#, 'train']:
    cleaned = dict()
    
    for s_or_t in ['source', 'target']:
        f = variant+'.wp_'+s_or_t
    
        with open(f, 'r') as file:
            text = file.readlines()
        detokened = []
        for ind in range(0,len(text)):
            detokened.append(md.detokenize(text[ind:ind+1]).replace('<newline>', '\n'))
        assert len(text)==len(detokened), "text and detokened are not the same length!"
        cleaned[variant+'_'+s_or_t] = detokened
        
    pd.DataFrame.from_dict(cleaned).to_csv(variant+'_dataframe.csv', index=False)

# %%
df = pd.DataFrame.from_dict(cleaned)

# %%
df.head()
# Out:
#                                          test_source  \
# 0  [WP] Leonardo DiCaprio in a fit of rage begins...
# 1    [CW] Kill the writer in first-person narrative.
# 2  [EU] Sean Bean has a hard time leaving his rol...
# 3  [WP] A kid doodling in a math class accidental...
# 4  [WP] As a Space marine you have an allowance o...
#
#                                          test_target
# 0  The wet marble floor pressed on his cheek like...
# 1  It's been three days since my boyfriend pissed...
# 2  George fled. Not terrifically fast, not at his...
# 3  It was dark and Levi was pretty sure he was ly...
# 4  ``Hi dad! ''\n \n The words snap me from my th...

# %%
import numpy as np
df['test_target_200'] = df['test_target'].apply(lambda x: ' '.join(x.split(' ')[:200]))
df['Prompt'] = df['test_source'].str[4:] + " \n "+df['test_target_200'] 
df.head()
# Out:
#                                          test_source  \
# 0  [WP] Leonardo DiCaprio in a fit of rage begins...
# 1    [CW] Kill the writer in first-person narrative.
# 2  [EU] Sean Bean has a hard time leaving his rol...
# 3  [WP] A kid doodling in a math class accidental...
# 4  [WP] As a Space marine you have an allowance o...
#
#                                          test_target  \
# 0  The wet marble floor pressed on his cheek like...
# 1  It's been three days since my boyfriend pissed...
# 2  George fled. Not terrifically fast, not at his...
# 3  It was dark and Levi was pretty sure he was ly...
# 4  ``Hi dad! ''\n \n The words snap me from my th...
#
#                                      test_target_200  \
# 0  The wet marble floor pressed on his cheek like...
# 1  It's been three days since my boyfriend pissed...
# 2  George fled. Not terrifically fast, not at his...
# 3  It was dark and Levi was pretty sure he was ly...
# 4  ``Hi dad! ''\n \n The words snap me from my th...
#
#                                               Prompt
# 0   Leonardo DiCaprio in a fit of rage begins to ...
# 1   Kill the writer in first-person narrative. \n...
# 2   Sean Bean has a hard time leaving his role as...
# 3   A kid doodling in a math class accidentally c...
# 4   As a Space marine you have an allowance of on...

# %%
df['Prompt'] = df['Prompt'].apply(lambda x: x.replace('`` ', ' ``'))

# %%
df['Prompt'].head(1000)
# Out:
# 0       Leonardo DiCaprio in a fit of rage begins to ...
# 1       Kill the writer in first-person narrative. \n...
# 2       Sean Bean has a hard time leaving his role as...
# 3       A kid doodling in a math class accidentally c...
# 4       As a Space marine you have an allowance of on...
# 5       ``Shut the dog up. '' \n “Shut the dog up, ” ...
# 6       A man finally discovers his superpower... wel...
# 7       Reddit buys the moon \n Dickbutt... That was ...
# 8       You have a very shitty type of precognition. ...
# 9       ``Before we allow humankind to live among us ...
# 10      A magical mirror shows your reflection and yo...
# 11      A person with a high school education gets se...
# 12      Everyone has a reaper. The further away it is...
# 13      A person with a high school education gets se...
# 14      After brushing your teeth in the morning you ...
# 15      While searching the site of a disaster, you f...
# 16      While walking home from work one day, someone...
# 17      Fabricate an inspiring encounter with a stran...
# 18      In your favourite fictional universe, the vil...
# 19      Write the same scene at least twice, making o...
# 20     trained Writing [WP] Write a story sentence by...
# 21      You live in a world were a drug exists that a...
# 22      You live in a world where light helps you ret...
# 23      Killing any creature inflicts an illness or b...
# 24      Aliens have arrived, and ask for a single hum...
# 25      ``And that was the first of the three lies......
# 26      You just started a new job in a large office ...
# 27      A cell in your body is just your average midd...
# 28      You are hiking in the woods when you hear a d...
# 29      The Fourth Wall has been breached and our wor...
#                              ...
# 970     It suddenly becomes possible to gain XP and l...
# 971     Floating Away \n I know how the bastards will...
# 972     Your kind has been enslaved by humanity for h...
# 973     You are a homeless person washing yourself in...
# 974     Michael Fishbein, Rogue Accountant \n ``What'...
# 975     Two undercover cops try to arrest each other ...
# 976     Every sentient species in the universe receiv...
# 977     Your first question upon arriving in the afte...
# 978     An animal is about to sacrifice himself for h...
# 979     Tell a story solely through someone's interne...
# 980     A fantastic new product just came out - when ...
# 981     The Long Road \n Many moments passed, as I st...
# 982     Mankind launches a Lawsuit against Heaven and...
# 983     A single pokemon appears in the real world. \...
# 984     In the future, every human born lives for exa...
# 985     Advances in technology have lengthened human ...
# 986     Describe the first person you ever fell in lo...
# 987     a sappy romance story gone wrong. \n “I love ...
# 988     A Colonel/General from the American Civil War...
# 989     Sunday Free Write: Leave A Story, Leave A Com...
# 990     ``Almost all communication with the West coas...
# 991     You use a public restroom, and the graffiti o...
# 992     You and your wife wear rings that let you fee...
# 993     We live in a world where exercise causes our ...
# 994     You are Captain aboard a pirate ship. Delieve...
# 995     You are a sociopath in a post apocalyptic env...
# 996     You run an RPG pawn shop. You haggle with adv...
# 997     after dying god informs you that hell is a my...
# 998     Trees are the resting place of a soul. \n Fro...
# 999     People have a single verb as a power, and fig...
# Name: Prompt, Length: 1000, dtype: object

# %%
df.to_csv(variant+'_dataframe.csv', index=False)
